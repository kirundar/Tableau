# %%
import pandas as pd
import glob
from pandas import *

# %%
trips = pd.read_csv("citiBike2017_q4.csv")

# %%
trips.head()
# Out:
#       Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0  10/1/17                                              55503
# 1  10/2/17                                              65509
# 2  10/3/17                                              69105
# 3  10/4/17                                              71453
# 4  10/5/17                                              70173
#
#    Miles traveled today (midnight to 11:59 pm)  \
# 0                                       139011
# 1                                       141748
# 2                                       135800
# 3                                       150324
# 4                                       150437
#
#    Total Annual Members (All Time)  \
# 0                           246193
# 1                           246402
# 2                           246566
# 3                           246742
# 4                           246893
#
#    24-Hour Passes Purchased (midnight to 11:59 pm)  \
# ...

# %%
# need to add all of the "trips over the past 24 hours data" for 2017
path =r'2017_data' # use your path
allFiles = glob.glob(path + "/*.csv")
frame = pd.DataFrame()
list_ = []
for file_ in allFiles:
    dataFrame = pd.read_csv(file_,index_col=None, header=0)
    list_.append(dataFrame)
dataFrame = pd.concat(list_)

# %%
dataFrame.head()
# Out:
#      Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0  4/1/17                                              23849
# 1  4/2/17                                              39779
# 2  4/3/17                                              43484
# 3  4/4/17                                              29990
# 4  4/5/17                                              47635
#
#    Miles traveled today (midnight to 11:59 pm)  \
# 0                                        67299
# 1                                       130087
# 2                                       104217
# 3                                        63091
# 4                                       108281
#
#    Total Annual Members (All Time)  \
# 0                           210739
# 1                           210915
# 2                           211075
# 3                           211171
# 4                           211310
#
#    24-Hour Passes Purchased (midnight to 11:59 pm)  \
# ...

# %%
total_trips = dataFrame['Trips over the past 24-hours (midnight to 11:59pm)'].sum()

# %%
total_trips
# Out:
# 16365695

# %%
dataFrame['cum_trips'] = dataFrame['Trips over the past 24-hours (midnight to 11:59pm)'].cumsum()

# %%
dataFrame.head()
# Out:
#      Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0  4/1/17                                              23849
# 1  4/2/17                                              39779
# 2  4/3/17                                              43484
# 3  4/4/17                                              29990
# 4  4/5/17                                              47635
#
#    Miles traveled today (midnight to 11:59 pm)  \
# 0                                        67299
# 1                                       130087
# 2                                       104217
# 3                                        63091
# 4                                       108281
#
#    Total Annual Members (All Time)  \
# 0                           210739
# 1                           210915
# 2                           211075
# 3                           211171
# 4                           211310
#
#    24-Hour Passes Purchased (midnight to 11:59 pm)  \
# ...

# %%
merged = pd.read_csv("winter/winter1.csv")
q4 = pd.read_csv("2017_data/citiBike2017_q4.csv")

# %%
merged.head()
# Out:
#    tripduration     starttime      stoptime  start station id  \
# 0           370  11/1/17 0:04  11/1/17 0:10              3199
# 1            96  11/1/17 0:05  11/1/17 0:07              3211
# 2            73  11/1/17 0:09  11/1/17 0:11              3275
# 3           162  11/1/17 0:14  11/1/17 0:16              3275
# 4           214  11/1/17 0:23  11/1/17 0:27              3276
#
#   start station name  start station latitude  start station longitude  \
# 0       Newport Pkwy               40.728745               -74.032108
# 1         Newark Ave               40.721525               -74.046305
# 2     Columbus Drive               40.718355               -74.038914
# 3     Columbus Drive               40.718355               -74.038914
# 4   Marin Light Rail               40.714584               -74.042817
#
#    end station id end station name  end station latitude  \
# 0            3639       Harborside             40.719252
# ...

# %%
q4.head()
# Out:
#       Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0  10/1/17                                              55503
# 1  10/2/17                                              65509
# 2  10/3/17                                              69105
# 3  10/4/17                                              71453
# 4  10/5/17                                              70173
#
#    Miles traveled today (midnight to 11:59 pm)  \
# 0                                       139011
# 1                                       141748
# 2                                       135800
# 3                                       150324
# 4                                       150437
#
#    Total Annual Members (All Time)  \
# 0                           246193
# 1                           246402
# 2                           246566
# 3                           246742
# 4                           246893
#
#    24-Hour Passes Purchased (midnight to 11:59 pm)  \
# ...

# %%
frames = [q4, merged]

result = pd.concat(frames, axis=1)

# %%
result.head()
# Out:
#       Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0  10/1/17                                            55503.0
# 1  10/2/17                                            65509.0
# 2  10/3/17                                            69105.0
# 3  10/4/17                                            71453.0
# 4  10/5/17                                            70173.0
#
#    Miles traveled today (midnight to 11:59 pm)  \
# 0                                     139011.0
# 1                                     141748.0
# 2                                     135800.0
# 3                                     150324.0
# 4                                     150437.0
#
#    Total Annual Members (All Time)  \
# 0                         246193.0
# 1                         246402.0
# 2                         246566.0
# 3                         246742.0
# 4                         246893.0
#
#    24-Hour Passes Purchased (midnight to 11:59 pm)  \
# ...

# %%
result.to_csv('mileage.csv')
